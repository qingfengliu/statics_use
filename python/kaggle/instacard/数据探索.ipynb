# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import xgboost as xgb
import joblib
from sklearn.model_selection import train_test_split

data_all=pd.read_csv(r'D:\书籍资料整理\kaggle\instacard\宽表.csv')
data_all.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2539329        1    prior             1          2                  8
# 2   2539329        1    prior             1          2                  8
# 3   2539329        1    prior             1          2                  8
# 4   2539329        1    prior             1          2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN       196.0                1.0        0.0
# 1                     NaN     14084.0                2.0        0.0
# 2                     NaN     12427.0                3.0        0.0
# 3                     NaN     26088.0                4.0        0.0
# 4                     NaN     26405.0                5.0        0.0
#
#                               product_name  aisle_id  department_id  \
# ...

# %%
data_all['eval_set'].value_counts()
# Out:
# prior    32434489
# train     1384617
# test        75000
# Name: eval_set, dtype: int64

# %%
data_all[data_all['eval_set']=='test'].head()
# Out:
#       order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 384    2774568        3     test            13          5                 15
# 403     329954        4     test             6          3                 12
# 464    1528013        6     test             4          3                 16
# 1086   1376945       11     test             8          6                 11
# 1161   1356845       12     test             6          1                 20
#
#       days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 384                     11.0         NaN                NaN        NaN
# 403                     30.0         NaN                NaN        NaN
# 464                     22.0         NaN                NaN        NaN
# 1086                     8.0         NaN                NaN        NaN
# 1161                    30.0         NaN                NaN        NaN
#
#      product_name  aisle_id  department_id aisle department
# ...
